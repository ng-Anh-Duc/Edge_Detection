# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/gdrive/MyDrive/duc.jpg', 0)
cv2_imshow(np.array(image))

sobelx = cv2.Sobel(image, cv2.CV_64F,0,1)
cv2_imshow(np.array(sobelx))
cv2.imwrite('/content/gdrive/MyDrive/Duc_Edge.jpg', sobelx)
# Out:
# <PIL.Image.Image image mode=L size=960x951 at 0x7F587C5A9720>
# <PIL.Image.Image image mode=L size=960x951 at 0x7F587C5A9720>
# True
